# %% [markdown]
# # braid exploration
#
# Walkthrough of the polymorphic spine.

# %%
import braid
print(f"braid v{braid.__version__}")
print(f"categories: {len(braid.registry.categories())}")
print(f"concretes:  {sum(len(braid.registry.available(c)) for c in braid.registry.categories())}")

# %%
from braid.registry_test_helpers import getstore  # noqa: F401  type: ignore  # isort: skip
from braid.registry_test_helpers import getstore
import numpy as np
from braid.testing.fixtures import tinycatalog
